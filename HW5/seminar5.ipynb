# %% [markdown]
# ## Семинар 5: "Улучшение сходимости нейросетей"

# %%
import numpy as np
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
import torch
from torch import nn
import torch.nn.functional as F
from torch.autograd import Variable
from torch.utils.data import DataLoader
from torchvision.datasets import MNIST
from torchvision import transforms
# %matplotlib inline

# %% [markdown]
# На этом семинаре мы попробуем улучшить результаты, полученные на предыдущем занятии
# Для этого нам понадобятся следующие вещи:
# * Инициализация весов
# * Dropout
# * Batch Normalization

# %% [markdown]
# ### Часть 1: Инициализация весов

# %% [markdown]
# Будем использовать MNIST для обучения:

# %%
# Dataloader
to_numpy = lambda x: x.numpy()
transform = transforms.Compose([
   transforms.ToTensor(),
   transforms.Normalize((0.1307,), (0.3081,))
])

train_dataset = MNIST('.', train=True, download=True, transform=transform)
test_dataset = MNIST('.', train=False, transform=transform)

train_loader = DataLoader(train_dataset, batch_size=128, shuffle=True)
test_loader = DataLoader(test_dataset, batch_size=128, shuffle=True)
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████| 9.91M/9.91M [00:27<00:00, 362kB/s]
# 100%|█████████████████████████████████████████████████████████████████████████████| 28.9k/28.9k [00:01<00:00, 23.3kB/s]
# 100%|██████████████████████████████████████████████████████████████████████████████| 1.65M/1.65M [00:03<00:00, 418kB/s]
# 100%|█████████████████████████████████████████████████████████████████████████████| 4.54k/4.54k [00:00<00:00, 1.49MB/s]

# %%
images_train, labels_train = next(iter(train_loader))

# %%
## Usage example:
for X, y in train_loader:
    X = X.view(X.size(0), -1)
    X = X.numpy() ### Converts torch.Tensor to numpy array
    y = y.numpy()
    break

# %%
plt.figure(figsize=(6, 7))
for i in range(25):
    plt.subplot(5, 5, i+1)
    plt.imshow(X[i].reshape(28, 28), cmap=plt.cm.Greys_r)
    plt.title(y[i])
    plt.axis('off')

# %% [markdown]
# Создадим два линейных слоя и инициализируем их случайным образом. Для этого используем uniform распределение с нулевым средним и большим отклонением.

# %%
def init_layer(layer, mean=0, std=1):
    # Тут надо быть аккуратным — можно случайно создать копию и менять значения у копии
    weight = layer.state_dict()['weight']
    bias = layer.state_dict()['bias']
    bias.zero_()
    weight.normal_(mean=mean, std=std)

def forward_hook(self, input_, output):
    std = input_[0].std().item()
    print('forward', std)

def backward_hook(self, grad_input, grad_output):
    std = grad_input[0].std().item()
    print('backward', std)

# %% [markdown]
# На вход передаем изображение 28x28, на выходе -- вероятности 10 классов.

# %%
layer_1 = nn.Linear(28*28, 500)
layer_2 = nn.Linear(500, 10)

layer_1.register_forward_hook(forward_hook)
layer_2.register_forward_hook(forward_hook)

layer_1.register_backward_hook(backward_hook)
layer_2.register_backward_hook(backward_hook)

init_layer(layer_1)
init_layer(layer_2)

# %% [markdown]
# Соберем все вместе, используя ReLU в качестве функции активации:

# %%
network = nn.Sequential(
    layer_1,
    nn.ReLU(),
    layer_2
)

# %% [markdown]
# Посчитаем дисперсию активаций и диспресию градиентов:

# %%
n_objects = 100
X = images_train[:n_objects].view(n_objects, -1).data
y = labels_train[:n_objects].data
activations = network(X)
loss_fn = torch.nn.NLLLoss()
optimizer = torch.optim.Adam(network.parameters(), lr=0.001)
loss = loss_fn(activations, y)
loss.backward()
# Out:
# forward 0.977334201335907
# forward 16.159603118896484
# backward 0.02666666731238365
# backward 0.19549404084682465
# C:\Users\Uliana\AppData\Local\Programs\Python\Python310\lib\site-packages\torch\nn\modules\module.py:1864: FutureWarning: Using a non-full backward hook when the forward contains multiple autograd Nodes is deprecated and will be removed in future versions. This hook will be missing some grad_input. Please use register_full_backward_hook to get the documented behavior.
#   self._maybe_warn_non_full_backward_hook(args, result, grad_fn)

# %% [markdown]
# Теперь попробуем использовать инициализацию He:<br>
# ![image.png](data:image/png;base64,...)

# %%
layer_1 = nn.Linear(28*28, 256)
layer_2 = nn.Linear(256, 10)

layer_1.register_forward_hook(forward_hook)
layer_2.register_forward_hook(forward_hook)

layer_1.register_backward_hook(backward_hook)
layer_2.register_backward_hook(backward_hook)

init_layer(layer_1, 0, 2 / 500)
init_layer(layer_2, 0, 2 / 10)

# %%
network = nn.Sequential(
    layer_1,
    nn.ReLU(),
    layer_2
)

n_objects = 100
X = images_train[:n_objects].view(n_objects, -1).data
y = labels_train[:n_objects].data
activations = network(X)
loss_fn = torch.nn.NLLLoss()
optimizer = torch.optim.Adam(network.parameters(), lr=0.001)
loss = loss_fn(activations, y)
loss.backward()
# Out:
# forward 0.977334201335907
# forward 0.0658164918422699
# backward 0.02666666731238365
# backward 0.03911161795258522

# %%
layer_1 = nn.Linear(28*28, 256)
layer_2 = nn.Linear(256, 10)

layer_1.register_forward_hook(forward_hook)
layer_2.register_forward_hook(forward_hook)

layer_1.register_backward_hook(backward_hook)
layer_2.register_backward_hook(backward_hook)

init_layer(layer_1, 0, 2 / (28*28))
init_layer(layer_2, 0, 2 / 10)

# %%
network = nn.Sequential(
    layer_1,
    nn.ReLU(),
    layer_2
)

n_objects = 100
X = images_train[:n_objects].view(n_objects, -1).data
y = labels_train[:n_objects].data
activations = network(X)
loss_fn = torch.nn.NLLLoss()
optimizer = torch.optim.Adam(network.parameters(), lr=0.001)
loss = loss_fn(activations, y)
loss.backward()
# Out:
# forward 0.977334201335907
# forward 0.04163302853703499
# backward 0.02666666731238365
# backward 0.03656386584043503

# %% [markdown]
# ## Часть 2: Dropout

# %% [markdown]
# Реализуем Dropout:
#
# * Train: с вероятностью p занулим выход нейрона (например, p = 0.5)
# * Test: домножаем веса на вероятность сохранения
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Так как мы получаем на **следующем слое  выход из нейрона 0 при Dropout**, то туда **backward не пойдет**, поэтому он тут не нужно

# %%
class Dropout(nn.Module):
    def __init__(self, p=0.5):
        super(Dropout, self).__init__()
        self.p = p

    def forward(self, x):
        mask = torch.empty(x.shape).uniform_(0, 1).type(torch.floatTensor) 
        if self.training:
            mask = torch.where(mask > self.p, 1, 0) 
        else:
            mask =  torch.where(mask > self.p, 1, 1 - self.p) 

        return x * mask

# %% [markdown]
# Основа для сети, которую будем обучать:

# %%
class TestNetwork(nn.Module):
    def __init__(self, final_part):
        super().__init__()

        channels = 1

        self.conv_layers = nn.Sequential(
            nn.Conv2d(channels, 2, 3, padding=1),
            nn.MaxPool2d(2),
            nn.ReLU(),
            nn.Conv2d(2, 4, 3, padding=1),
            nn.MaxPool2d(2),
            nn.ReLU(),
        )

        #input_size = 7 * 7 * 4 = 196
        self.flatten = nn.Flatten()

        self.final_part = final_part

        self.log_softmax = nn.LogSoftmax(1)

    def forward(self, x):
        x = self.conv_layers(x)
        x = self.flatten(x)
        x = self.final_part(x)
        return self.log_softmax(x)

# %% [markdown]
# Добавим несколько слоев в конец сети:

# %%
layers = [
    nn.Linear(196, 150),
    nn.ReLU(),
    nn.Linear(150, 50),
    nn.ReLU(),
    nn.Linear(50, 10)
]

# %%
network = TestNetwork(nn.Sequential(*layers))
optimizer = torch.optim.Adam(network.parameters(), lr=0.001)
loss_fn = torch.nn.NLLLoss()

# %% [markdown]
# Обучим получившуюся сеть:

# %%
for epoch in range(10):
    network.train()
    for batch_idx, (images_train, labels_train) in enumerate(train_loader):
        optimizer.zero_grad()
        X = images_train.data
        y = labels_train.data
        output = network(X)
        loss = loss_fn(output, y)
        loss.backward()
        optimizer.step()

        if batch_idx % 100 == 0:
            print('Train Epoch: {} [{}/{} ({:.0f}%)]\tLoss: {:.6f}'.format(
            epoch, batch_idx * len(X), len(train_loader.dataset),
            100. * batch_idx / len(train_loader), loss.item()))

    network.eval()
    losses = []
    for batch_idx, (images_test, labels_test) in enumerate(test_loader):
        X = images_test.data
        y = labels_test.data
        output = network(X)
        loss = loss_fn(output, y)

        losses.append(loss.item())

    print('Test Epoch: {}\tLoss: {:.6f}'.format(
            epoch, np.mean(losses)))
# Out:
# Train Epoch: 0 [0/60000 (0%)]	Loss: 2.303238
# Train Epoch: 0 [12800/60000 (21%)]	Loss: 0.917329
# Train Epoch: 0 [25600/60000 (43%)]	Loss: 0.428646
# Train Epoch: 0 [38400/60000 (64%)]	Loss: 0.244771
# Train Epoch: 0 [51200/60000 (85%)]	Loss: 0.288855
# Test Epoch: 0	Loss: 0.220786
# Train Epoch: 1 [0/60000 (0%)]	Loss: 0.295198
# Train Epoch: 1 [12800/60000 (21%)]	Loss: 0.196963
# Train Epoch: 1 [25600/60000 (43%)]	Loss: 0.317859
# Train Epoch: 1 [38400/60000 (64%)]	Loss: 0.141559
# Train Epoch: 1 [51200/60000 (85%)]	Loss: 0.171779
# Test Epoch: 1	Loss: 0.140082
# Train Epoch: 2 [0/60000 (0%)]	Loss: 0.161502
# Train Epoch: 2 [12800/60000 (21%)]	Loss: 0.171475
# Train Epoch: 2 [25600/60000 (43%)]	Loss: 0.157680
# Train Epoch: 2 [38400/60000 (64%)]	Loss: 0.187318
# Train Epoch: 2 [51200/60000 (85%)]	Loss: 0.126841
# Test Epoch: 2	Loss: 0.114140
# Train Epoch: 3 [0/60000 (0%)]	Loss: 0.120525
# Train Epoch: 3 [12800/60000 (21%)]	Loss: 0.066392
# Train Epoch: 3 [25600/60000 (43%)]	Loss: 0.133895
# Train Epoch: 3 [38400/60000 (64%)]	Loss: 0.092021
# Train Epoch: 3 [51200/60000 (85%)]	Loss: 0.148683
# Test Epoch: 3	Loss: 0.100420
# Train Epoch: 4 [0/60000 (0%)]	Loss: 0.101434
# Train Epoch: 4 [12800/60000 (21%)]	Loss: 0.078263
# Train Epoch: 4 [25600/60000 (43%)]	Loss: 0.145960
# Train Epoch: 4 [38400/60000 (64%)]	Loss: 0.147237
# Train Epoch: 4 [51200/60000 (85%)]	Loss: 0.174994
# Test Epoch: 4	Loss: 0.087041
# Train Epoch: 5 [0/60000 (0%)]	Loss: 0.091715
# Train Epoch: 5 [12800/60000 (21%)]	Loss: 0.088445
# Train Epoch: 5 [25600/60000 (43%)]	Loss: 0.052567
# Train Epoch: 5 [38400/60000 (64%)]	Loss: 0.168732
# Train Epoch: 5 [51200/60000 (85%)]	Loss: 0.030789
# Test Epoch: 5	Loss: 0.085995
# Train Epoch: 6 [0/60000 (0%)]	Loss: 0.040534
# Train Epoch: 6 [12800/60000 (21%)]	Loss: 0.035138
# Train Epoch: 6 [25600/60000 (43%)]	Loss: 0.037085
# Train Epoch: 6 [38400/60000 (64%)]	Loss: 0.105241
# Train Epoch: 6 [51200/60000 (85%)]	Loss: 0.033768
# Test Epoch: 6	Loss: 0.075426
# Train Epoch: 7 [0/60000 (0%)]	Loss: 0.043226
# Train Epoch: 7 [12800/60000 (21%)]	Loss: 0.130950
# Train Epoch: 7 [25600/60000 (43%)]	Loss: 0.068035
# Train Epoch: 7 [38400/60000 (64%)]	Loss: 0.023335
# Train Epoch: 7 [51200/60000 (85%)]	Loss: 0.094429
# Test Epoch: 7	Loss: 0.070823
# Train Epoch: 8 [0/60000 (0%)]	Loss: 0.122436
# Train Epoch: 8 [12800/60000 (21%)]	Loss: 0.021821
# Train Epoch: 8 [25600/60000 (43%)]	Loss: 0.029544
# Train Epoch: 8 [38400/60000 (64%)]	Loss: 0.026348
# Train Epoch: 8 [51200/60000 (85%)]	Loss: 0.017657
# Test Epoch: 8	Loss: 0.070402
# Train Epoch: 9 [0/60000 (0%)]	Loss: 0.065367
# Train Epoch: 9 [12800/60000 (21%)]	Loss: 0.016518
# Train Epoch: 9 [25600/60000 (43%)]	Loss: 0.027698
# Train Epoch: 9 [38400/60000 (64%)]	Loss: 0.059662
# Train Epoch: 9 [51200/60000 (85%)]	Loss: 0.064265
# Test Epoch: 9	Loss: 0.067537

# %%
layers = [
    nn.Linear(196, 150),
    nn.ReLU(),
    Dropout(),
    nn.Linear(150, 50),
    nn.ReLU(),
    Dropout(),
    nn.Linear(50, 10)
]

# %%
network = TestNetwork(nn.Sequential(*layers))
optimizer = torch.optim.Adam(network.parameters(), lr=0.001)
loss_fn = torch.nn.NLLLoss()

# %%
for epoch in range(10):
    network.train()
    for batch_idx, (images_train, labels_train) in enumerate(train_loader):
        optimizer.zero_grad()
        X = images_train.data
        y = labels_train.data
        output = network(X)
        loss = loss_fn(output, y)
        loss.backward()
        optimizer.step()

        if batch_idx % 100 == 0:
            print('Train Epoch: {} [{}/{} ({:.0f}%)]\tLoss: {:.6f}'.format(
            epoch, batch_idx * len(X), len(train_loader.dataset),
            100. * batch_idx / len(train_loader), loss.item()))

    network.eval()
    losses = []
    for batch_idx, (images_test, labels_test) in enumerate(test_loader):
        X = images_test.data
        y = labels_test.data
        output = network(X)
        loss = loss_fn(output, y)

        losses.append(loss.item())

    print('Test Epoch: {}\tLoss: {:.6f}'.format(
            epoch, np.mean(losses)))
# Out:
# Train Epoch: 0 [0/60000 (0%)]	Loss: 2.299135
# Train Epoch: 0 [12800/60000 (21%)]	Loss: 1.246462
# Train Epoch: 0 [25600/60000 (43%)]	Loss: 0.667639
# Train Epoch: 0 [38400/60000 (64%)]	Loss: 0.446200
# Train Epoch: 0 [51200/60000 (85%)]	Loss: 0.417653
# Test Epoch: 0	Loss: 0.229165
# Train Epoch: 1 [0/60000 (0%)]	Loss: 0.572721
# Train Epoch: 1 [12800/60000 (21%)]	Loss: 0.469281
# Train Epoch: 1 [25600/60000 (43%)]	Loss: 0.299895
# Train Epoch: 1 [38400/60000 (64%)]	Loss: 0.472880
# Train Epoch: 1 [51200/60000 (85%)]	Loss: 0.447614
# Test Epoch: 1	Loss: 0.156659
# Train Epoch: 2 [0/60000 (0%)]	Loss: 0.161697
# Train Epoch: 2 [12800/60000 (21%)]	Loss: 0.193012
# Train Epoch: 2 [25600/60000 (43%)]	Loss: 0.270669
# Train Epoch: 2 [38400/60000 (64%)]	Loss: 0.307837
# Train Epoch: 2 [51200/60000 (85%)]	Loss: 0.306449
# Test Epoch: 2	Loss: 0.140270
# Train Epoch: 3 [0/60000 (0%)]	Loss: 0.388160
# Train Epoch: 3 [12800/60000 (21%)]	Loss: 0.297556
# Train Epoch: 3 [25600/60000 (43%)]	Loss: 0.277096
# Train Epoch: 3 [38400/60000 (64%)]	Loss: 0.344552
# Train Epoch: 3 [51200/60000 (85%)]	Loss: 0.108481
# Test Epoch: 3	Loss: 0.109368
# Train Epoch: 4 [0/60000 (0%)]	Loss: 0.225774
# Train Epoch: 4 [12800/60000 (21%)]	Loss: 0.393559
# Train Epoch: 4 [25600/60000 (43%)]	Loss: 0.166117
# Train Epoch: 4 [38400/60000 (64%)]	Loss: 0.148207
# Train Epoch: 4 [51200/60000 (85%)]	Loss: 0.227398
# Test Epoch: 4	Loss: 0.099763
# Train Epoch: 5 [0/60000 (0%)]	Loss: 0.196712
# Train Epoch: 5 [12800/60000 (21%)]	Loss: 0.228845
# Train Epoch: 5 [25600/60000 (43%)]	Loss: 0.152649
# Train Epoch: 5 [38400/60000 (64%)]	Loss: 0.161883
# Train Epoch: 5 [51200/60000 (85%)]	Loss: 0.181064
# Test Epoch: 5	Loss: 0.093683
# Train Epoch: 6 [0/60000 (0%)]	Loss: 0.126792
# Train Epoch: 6 [12800/60000 (21%)]	Loss: 0.206471
# Train Epoch: 6 [25600/60000 (43%)]	Loss: 0.132333
# Train Epoch: 6 [38400/60000 (64%)]	Loss: 0.201960
# Train Epoch: 6 [51200/60000 (85%)]	Loss: 0.180934
# Test Epoch: 6	Loss: 0.094997
# Train Epoch: 7 [0/60000 (0%)]	Loss: 0.265091
# Train Epoch: 7 [12800/60000 (21%)]	Loss: 0.145893
# Train Epoch: 7 [25600/60000 (43%)]	Loss: 0.226680
# Train Epoch: 7 [38400/60000 (64%)]	Loss: 0.289323
# Train Epoch: 7 [51200/60000 (85%)]	Loss: 0.253014
# Test Epoch: 7	Loss: 0.084414
# Train Epoch: 8 [0/60000 (0%)]	Loss: 0.128829
# Train Epoch: 8 [12800/60000 (21%)]	Loss: 0.182874
# Train Epoch: 8 [25600/60000 (43%)]	Loss: 0.087101
# Train Epoch: 8 [38400/60000 (64%)]	Loss: 0.283677
# Train Epoch: 8 [51200/60000 (85%)]	Loss: 0.129914
# Test Epoch: 8	Loss: 0.080027
# Train Epoch: 9 [0/60000 (0%)]	Loss: 0.087989
# Train Epoch: 9 [12800/60000 (21%)]	Loss: 0.121302
# Train Epoch: 9 [25600/60000 (43%)]	Loss: 0.111083
# Train Epoch: 9 [38400/60000 (64%)]	Loss: 0.137252
# Train Epoch: 9 [51200/60000 (85%)]	Loss: 0.087425
# Test Epoch: 9	Loss: 0.082978

# %% [markdown]
# Видно характерное для Dropout поведение, что **лосс резко падает, а потом больше**. Это **"отключили плохие"** нейроны.
# Train Epoch: 1 [0/60000 (0%)]	Loss: 0.572721
# Train Epoch: 1 [12800/60000 (21%)]	Loss: **0.469281**
# Train Epoch: 1 [25600/60000 (43%)]	Loss: **0.299895**
# Train Epoch: 1 [38400/60000 (64%)]	Loss: **0.472880**
# Train Epoch: 1 [51200/60000 (85%)]	Loss: 0.447614
# При этом это **характерно на первых эпохах** обучения, а потом Dropaut показывает, что лосс быстрее выходит на плато.
